# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_path = 'C:/Users/User/Documents/data_analysis_wit_python1/mod2.csv'
df1 = pd.read_csv(file_path)
df = df1

# %%
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]

# %%
df
# Out:
#      Unnamed: 0  symboling  normalized-losses         make fuel-type  \
# 0             0          3                NaN  alfa-romero       gas
# 1             1          1                NaN  alfa-romero       gas
# 2             2          2              164.0         audi       gas
# 3             3          2              164.0         audi       gas
# 4             4          2                NaN         audi       gas
# ..          ...        ...                ...          ...       ...
# 199         199         -1               95.0        volvo       gas
# 200         200         -1               95.0        volvo       gas
# 201         201         -1               95.0        volvo       gas
# 202         202         -1               95.0        volvo    diesel
# 203         203         -1               95.0        volvo       gas
#
#     aspiration num-of-doors   body-style drive-wheels engine-location  ...  \
# 0          std          two  convertible          rwd           front  ...
# 1          std          two    hatchback          rwd           front  ...
# 2          std         four        sedan          fwd           front  ...
# 3          std         four        sedan          4wd           front  ...
# 4          std          two        sedan          fwd           front  ...
# ..         ...          ...          ...          ...             ...  ...
# 199        std         four        sedan          rwd           front  ...
# 200      turbo         four        sedan          rwd           front  ...
# 201        std         four        sedan          rwd           front  ...
# 202      turbo         four        sedan          rwd           front  ...
# 203      turbo         four        sedan          rwd           front  ...
#
#      engine-size  fuel-system  bore  stroke  compression-ratio horsepower  \
# 0            130         mpfi  3.47    2.68                9.0      111.0
# 1            152         mpfi  2.68    3.47                9.0      154.0
# 2            109         mpfi  3.19    3.40               10.0      102.0
# 3            136         mpfi  3.19    3.40                8.0      115.0
# 4            136         mpfi  3.19    3.40                8.5      110.0
# ..           ...          ...   ...     ...                ...        ...
# 199          141         mpfi  3.78    3.15                9.5      114.0
# 200          141         mpfi  3.78    3.15                8.7      160.0
# 201          173         mpfi  3.58    2.87                8.8      134.0
# 202          145          idi  3.01    3.40               23.0      106.0
# 203          141         mpfi  3.78    3.15                9.5      114.0
#
#     peak-rpm  city-mpg highway-mpg    price
# 0     5000.0        21          27  16500.0
# 1     5000.0        19          26  16500.0
# 2     5500.0        24          30  13950.0
# 3     5500.0        18          22  17450.0
# 4     5500.0        19          25  15250.0
# ..       ...       ...         ...      ...
# 199   5400.0        23          28  16845.0
# 200   5300.0        19          25  19045.0
# 201   5500.0        18          23  21485.0
# 202   4800.0        26          27  22470.0
# 203   5400.0        19          25  22625.0
#
# [204 rows x 27 columns]

# %%
# We remove the Unnamed: column
df.drop('Unnamed: 0',axis= 1, inplace= True)

# %%
# Replacing missing values for each column
avgsym = df['symboling'].max()
df['symboling'] = df['symboling'].replace(np.NaN, avgsym)
df['symboling']
# Out:
# 0      3
# 1      1
# 2      2
# 3      2
# 4      2
#       ..
# 199   -1
# 200   -1
# 201   -1
# 202   -1
# 203   -1
# Name: symboling, Length: 204, dtype: int64

# %%
mississ = df.isnull()
for columns in mississ.columns.values.tolist():
    print(mississ[columns].value_counts())
# Out:
# False    204
# Name: symboling, dtype: int64
# False    164
# True      40
# Name: normalized-losses, dtype: int64
# False    204
# Name: make, dtype: int64
# False    204
# Name: fuel-type, dtype: int64
# False    204
# Name: aspiration, dtype: int64
# False    202
# True       2
# Name: num-of-doors, dtype: int64
# False    204
# Name: body-style, dtype: int64
# False    204
# Name: drive-wheels, dtype: int64
# False    204
# Name: engine-location, dtype: int64
# False    204
# Name: wheel-base, dtype: int64
# False    204
# Name: length, dtype: int64
# False    204
# Name: width, dtype: int64
# False    204
# Name: height, dtype: int64
# False    204
# Name: curb-weight, dtype: int64
# False    204
# Name: engine-type, dtype: int64
# False    204
# Name: num-of-cylinders, dtype: int64
# False    204
# Name: engine-size, dtype: int64
# False    204
# Name: fuel-system, dtype: int64
# False    200
# True       4
# Name: bore, dtype: int64
# False    200
# True       4
# Name: stroke, dtype: int64
# False    204
# Name: compression-ratio, dtype: int64
# False    202
# True       2
# Name: horsepower, dtype: int64
# False    202
# True       2
# Name: peak-rpm, dtype: int64
# False    204
# Name: city-mpg, dtype: int64
# False    204
# Name: highway-mpg, dtype: int64
# False    200
# True       4
# Name: price, dtype: int64

# %%
avgnorm = df['normalized-losses'].mean()
df['normalized-losses'] = df['normalized-losses'].replace(np.NaN,avgnorm)

# %%
k = df['normalized-losses']. isnull()
k.value_counts()
# Out:
# False    204
# Name: normalized-losses, dtype: int64

# %%
avgasp
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6076/4069395049.py in <module>
# ----> 1 avgasp
#
# NameError: name 'avgasp' is not defined

# %%
avgasp = df['aspiration'].max()
df['aspiration'] = df['aspiration'].replace(np.NaN,avgasp)

# %%
avgpr = df['price'].mean()
df['price'] = df['price'].replace(np.NaN,avgpr)

# %%
df
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3              122.0  alfa-romero       gas        std
# 1            1              122.0  alfa-romero       gas        std
# 2            2              164.0         audi       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              122.0         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 199         -1               95.0        volvo       gas        std
# 200         -1               95.0        volvo       gas      turbo
# 201         -1               95.0        volvo       gas        std
# 202         -1               95.0        volvo    diesel      turbo
# 203         -1               95.0        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# 1            two    hatchback          rwd           front        94.5  ...
# 2           four        sedan          fwd           front        99.8  ...
# 3           four        sedan          4wd           front        99.4  ...
# 4            two        sedan          fwd           front        99.8  ...
# ..           ...          ...          ...             ...         ...  ...
# 199         four        sedan          rwd           front       109.1  ...
# 200         four        sedan          rwd           front       109.1  ...
# 201         four        sedan          rwd           front       109.1  ...
# 202         four        sedan          rwd           front       109.1  ...
# 203         four        sedan          rwd           front       109.1  ...
#
#      engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 0            130         mpfi  3.47    2.68               9.0      111.0
# 1            152         mpfi  2.68    3.47               9.0      154.0
# 2            109         mpfi  3.19    3.40              10.0      102.0
# 3            136         mpfi  3.19    3.40               8.0      115.0
# 4            136         mpfi  3.19    3.40               8.5      110.0
# ..           ...          ...   ...     ...               ...        ...
# 199          141         mpfi  3.78    3.15               9.5      114.0
# 200          141         mpfi  3.78    3.15               8.7      160.0
# 201          173         mpfi  3.58    2.87               8.8      134.0
# 202          145          idi  3.01    3.40              23.0      106.0
# 203          141         mpfi  3.78    3.15               9.5      114.0
#
#      peak-rpm city-mpg  highway-mpg    price
# 0      5000.0       21           27  16500.0
# 1      5000.0       19           26  16500.0
# 2      5500.0       24           30  13950.0
# 3      5500.0       18           22  17450.0
# 4      5500.0       19           25  15250.0
# ..        ...      ...          ...      ...
# 199    5400.0       23           28  16845.0
# 200    5300.0       19           25  19045.0
# 201    5500.0       18           23  21485.0
# 202    4800.0       26           27  22470.0
# 203    5400.0       19           25  22625.0
#
# [204 rows x 26 columns]

# %%
#  data formating
df['city-mpg'] = 235/df['city-mpg']
df.rename(columns = {'city-mpg':'city-L/100km'}, inplace= True)

# %%
df
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3              122.0  alfa-romero       gas        std
# 1            1              122.0  alfa-romero       gas        std
# 2            2              164.0         audi       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              122.0         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 199         -1               95.0        volvo       gas        std
# 200         -1               95.0        volvo       gas      turbo
# 201         -1               95.0        volvo       gas        std
# 202         -1               95.0        volvo    diesel      turbo
# 203         -1               95.0        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# 1            two    hatchback          rwd           front        94.5  ...
# 2           four        sedan          fwd           front        99.8  ...
# 3           four        sedan          4wd           front        99.4  ...
# 4            two        sedan          fwd           front        99.8  ...
# ..           ...          ...          ...             ...         ...  ...
# 199         four        sedan          rwd           front       109.1  ...
# 200         four        sedan          rwd           front       109.1  ...
# 201         four        sedan          rwd           front       109.1  ...
# 202         four        sedan          rwd           front       109.1  ...
# 203         four        sedan          rwd           front       109.1  ...
#
#      engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 0            130         mpfi  3.47    2.68               9.0      111.0
# 1            152         mpfi  2.68    3.47               9.0      154.0
# 2            109         mpfi  3.19    3.40              10.0      102.0
# 3            136         mpfi  3.19    3.40               8.0      115.0
# 4            136         mpfi  3.19    3.40               8.5      110.0
# ..           ...          ...   ...     ...               ...        ...
# 199          141         mpfi  3.78    3.15               9.5      114.0
# 200          141         mpfi  3.78    3.15               8.7      160.0
# 201          173         mpfi  3.58    2.87               8.8      134.0
# 202          145          idi  3.01    3.40              23.0      106.0
# 203          141         mpfi  3.78    3.15               9.5      114.0
#
#      peak-rpm city-L/100km  highway-mpg    price
# 0      5000.0         21.0           27  16500.0
# 1      5000.0         19.0           26  16500.0
# 2      5500.0         24.0           30  13950.0
# 3      5500.0         18.0           22  17450.0
# 4      5500.0         19.0           25  15250.0
# ..        ...          ...          ...      ...
# 199    5400.0         23.0           28  16845.0
# 200    5300.0         19.0           25  19045.0
# 201    5500.0         18.0           23  21485.0
# 202    4800.0         26.0           27  22470.0
# 203    5400.0         19.0           25  22625.0
#
# [204 rows x 26 columns]

# %%
df['price'].dtypes
# Out:
# dtype('int32')

# %%
df['price'] = df['price'].astype('int')

# %%
# Data Binning
bins= np.linspace(min(df['price']),max(df['price']),4)
group_names = {'Low', 'Medium', 'High'}
df['price-binned'] = pd.cut(df['price'], bins, labels = group_names)
df['price-binned'].value_counts()
# Out:
# High      173
# Medium     18
# Low        12
# Name: price-binned, dtype: int64

# %%
df
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3              122.0  alfa-romero       gas        std
# 1            1              122.0  alfa-romero       gas        std
# 2            2              164.0         audi       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              122.0         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 199         -1               95.0        volvo       gas        std
# 200         -1               95.0        volvo       gas      turbo
# 201         -1               95.0        volvo       gas        std
# 202         -1               95.0        volvo    diesel      turbo
# 203         -1               95.0        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# 1            two    hatchback          rwd           front        94.5  ...
# 2           four        sedan          fwd           front        99.8  ...
# 3           four        sedan          4wd           front        99.4  ...
# 4            two        sedan          fwd           front        99.8  ...
# ..           ...          ...          ...             ...         ...  ...
# 199         four        sedan          rwd           front       109.1  ...
# 200         four        sedan          rwd           front       109.1  ...
# 201         four        sedan          rwd           front       109.1  ...
# 202         four        sedan          rwd           front       109.1  ...
# 203         four        sedan          rwd           front       109.1  ...
#
#      engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 0            130         mpfi  3.47    2.68               9.0      111.0
# 1            152         mpfi  2.68    3.47               9.0      154.0
# 2            109         mpfi  3.19    3.40              10.0      102.0
# 3            136         mpfi  3.19    3.40               8.0      115.0
# 4            136         mpfi  3.19    3.40               8.5      110.0
# ..           ...          ...   ...     ...               ...        ...
# 199          141         mpfi  3.78    3.15               9.5      114.0
# 200          141         mpfi  3.78    3.15               8.7      160.0
# 201          173         mpfi  3.58    2.87               8.8      134.0
# 202          145          idi  3.01    3.40              23.0      106.0
# 203          141         mpfi  3.78    3.15               9.5      114.0
#
#      peak-rpm city-mpg  highway-mpg    price
# 0      5000.0       21           27  16500.0
# 1      5000.0       19           26  16500.0
# 2      5500.0       24           30  13950.0
# 3      5500.0       18           22  17450.0
# 4      5500.0       19           25  15250.0
# ..        ...      ...          ...      ...
# 199    5400.0       23           28  16845.0
# 200    5300.0       19           25  19045.0
# 201    5500.0       18           23  21485.0
# 202    4800.0       26           27  22470.0
# 203    5400.0       19           25  22625.0
#
# [204 rows x 26 columns]

# %%
# data normalization
li = df['length'] /df['length'].max()

# %%
df['length'] = li

# %%
dummy_variable_1=pd.get_dummies(df['fuel-type'])
dummy_variable_1.rename(columns={'diesel':'fuel-type-diesel', 'gas':'fuel-type-gas'},inplace=True)
df = pd.concat([df,dummy_variable_1], axis = 1)

# %%
df
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3              122.0  alfa-romero       gas        std
# 1            1              122.0  alfa-romero       gas        std
# 2            2              164.0         audi       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              122.0         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 199         -1               95.0        volvo       gas        std
# 200         -1               95.0        volvo       gas      turbo
# 201         -1               95.0        volvo       gas        std
# 202         -1               95.0        volvo    diesel      turbo
# 203         -1               95.0        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# 1            two    hatchback          rwd           front        94.5  ...
# 2           four        sedan          fwd           front        99.8  ...
# 3           four        sedan          4wd           front        99.4  ...
# 4            two        sedan          fwd           front        99.8  ...
# ..           ...          ...          ...             ...         ...  ...
# 199         four        sedan          rwd           front       109.1  ...
# 200         four        sedan          rwd           front       109.1  ...
# 201         four        sedan          rwd           front       109.1  ...
# 202         four        sedan          rwd           front       109.1  ...
# 203         four        sedan          rwd           front       109.1  ...
#
#      bore  stroke  compression-ratio  horsepower peak-rpm city-mpg  \
# 0    3.47    2.68                9.0       111.0   5000.0       21
# 1    2.68    3.47                9.0       154.0   5000.0       19
# 2    3.19    3.40               10.0       102.0   5500.0       24
# 3    3.19    3.40                8.0       115.0   5500.0       18
# 4    3.19    3.40                8.5       110.0   5500.0       19
# ..    ...     ...                ...         ...      ...      ...
# 199  3.78    3.15                9.5       114.0   5400.0       23
# 200  3.78    3.15                8.7       160.0   5300.0       19
# 201  3.58    2.87                8.8       134.0   5500.0       18
# 202  3.01    3.40               23.0       106.0   4800.0       26
# 203  3.78    3.15                9.5       114.0   5400.0       19
#
#      highway-mpg    price  fuel-type-diesel  fuel-type-gas
# 0             27  16500.0                 0              1
# 1             26  16500.0                 0              1
# 2             30  13950.0                 0              1
# 3             22  17450.0                 0              1
# 4             25  15250.0                 0              1
# ..           ...      ...               ...            ...
# 199           28  16845.0                 0              1
# 200           25  19045.0                 0              1
# 201           23  21485.0                 0              1
# 202           27  22470.0                 1              0
# 203           25  22625.0                 0              1
#
# [204 rows x 28 columns]

# %%
df.drop(['fuel-type'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6076/802778398.py in <module>
# ----> 1 df.drop(['fuel-type'], axis=1, inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['fuel-type'] not found in axis"

# %%
df
# Out:
#      symboling  normalized-losses         make aspiration num-of-doors  \
# 0            3              122.0  alfa-romero        std          two
# 1            1              122.0  alfa-romero        std          two
# 2            2              164.0         audi        std         four
# 3            2              164.0         audi        std         four
# 4            2              122.0         audi        std          two
# ..         ...                ...          ...        ...          ...
# 199         -1               95.0        volvo        std         four
# 200         -1               95.0        volvo      turbo         four
# 201         -1               95.0        volvo        std         four
# 202         -1               95.0        volvo      turbo         four
# 203         -1               95.0        volvo      turbo         four
#
#       body-style drive-wheels engine-location  wheel-base  length  ...  bore  \
# 0    convertible          rwd           front        88.6   168.8  ...  3.47
# 1      hatchback          rwd           front        94.5   171.2  ...  2.68
# 2          sedan          fwd           front        99.8   176.6  ...  3.19
# 3          sedan          4wd           front        99.4   176.6  ...  3.19
# 4          sedan          fwd           front        99.8   177.3  ...  3.19
# ..           ...          ...             ...         ...     ...  ...   ...
# 199        sedan          rwd           front       109.1   188.8  ...  3.78
# 200        sedan          rwd           front       109.1   188.8  ...  3.78
# 201        sedan          rwd           front       109.1   188.8  ...  3.58
# 202        sedan          rwd           front       109.1   188.8  ...  3.01
# 203        sedan          rwd           front       109.1   188.8  ...  3.78
#
#      stroke  compression-ratio horsepower peak-rpm  city-mpg highway-mpg  \
# 0      2.68                9.0      111.0   5000.0        21          27
# 1      3.47                9.0      154.0   5000.0        19          26
# 2      3.40               10.0      102.0   5500.0        24          30
# 3      3.40                8.0      115.0   5500.0        18          22
# 4      3.40                8.5      110.0   5500.0        19          25
# ..      ...                ...        ...      ...       ...         ...
# 199    3.15                9.5      114.0   5400.0        23          28
# 200    3.15                8.7      160.0   5300.0        19          25
# 201    2.87                8.8      134.0   5500.0        18          23
# 202    3.40               23.0      106.0   4800.0        26          27
# 203    3.15                9.5      114.0   5400.0        19          25
#
#        price  fuel-type-diesel  fuel-type-gas
# 0    16500.0                 0              1
# 1    16500.0                 0              1
# 2    13950.0                 0              1
# 3    17450.0                 0              1
# 4    15250.0                 0              1
# ..       ...               ...            ...
# 199  16845.0                 0              1
# 200  19045.0                 0              1
# 201  21485.0                 0              1
# 202  22470.0                 1              0
# 203  22625.0                 0              1
#
# [204 rows x 27 columns]

# %%
df.to_excel('completeClean.xls')
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_1560/3199552368.py:1: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   df.to_excel('completeClean.xls')
